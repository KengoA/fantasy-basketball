# %%
import os
import glob
import numpy as np
import pandas as pd
import pandas_profiling
import matplotlib.pyplot as plt

from tqdm import tqdm_notebook as tqdm
from datetime import datetime
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

# %%
cwd = os.getcwd().replace('/notebooks','')
data_dir = os.path.join(cwd, 'data')
np.random.seed(6)

# %%
# %matplotlib inline

# %%
#Concatenate all csv files under a directory
def csv_concatenate(folder_path):
    files = glob.glob(folder_path + "/*.csv")
    df_list = []
    for file in tqdm(files):
        df_list.append(pd.read_csv(file, parse_dates=True, infer_datetime_format=True))
    #Fill nan with 0s as some values are empty for percentage points
    df = pd.concat(df_list).fillna(0).reset_index(drop=True)
    return df

# %%
def calculate_MAE(pred, true):
    n = len(pred)
    abs_error = 0 
    for i in range(n):
        abs_error += abs(pred[i] - true[i])
    mae = abs_error/n
    return mae

# %%
def calculate_RMSE(pred, true):
    return np.sqrt(mean_squared_error(pred, true))

# %%
def calculate_FPTS(df):
    #Scoring rules based on https://www.draftkings.co.uk/help/rules/4
    multipliers = {'PTS':1, '3P': 0.5, 'TRB':1.25, 'AST':1.5, 'STL':2, 'BLK':2, 'TOV':-0.5}
    
    indices = len(df)
    fpts_list = []
    
    for i in tqdm(range(indices)):
        fpts = 0
        doubles = 0
        for stat, multiplier in multipliers.items():
            if stat in ['PTS', 'TRB', 'AST', 'STL', 'BLK']:
                if df.loc[i, stat] >= 10:
                    doubles += 1
            fpts += df.loc[i, stat]*multiplier
        if doubles >= 2:
            fpts += 1.5
        if doubles >= 3:
            fpts += 3
        fpts_list.append(fpts) 
        
    return fpts_list

# %%
def cross_val(reg_base, X, y, show_train=False):
    mae_results_train = []
    rmse_results_train = []
    
    mae_results_test = []
    rmse_results_test = []
    
    for k in tqdm(range(5)):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=k)
        reg = reg_base
        
        reg.fit(X_train, y_train)
        
        y_pred_train = reg.predict(X_train)
        
        mae_results_train.append(calculate_MAE(y_pred_train, y_train))
        rmse_results_train.append(calculate_RMSE(y_pred_train, y_train))
        
        y_pred_test = reg.predict(X_test)
        
        mae_results_test.append(calculate_MAE(y_pred_test, y_test))
        rmse_results_test.append(calculate_RMSE(y_pred_test, y_test))
    
    if show_train==True:
        print('[TRAIN]')
        print('MAE:', np.mean(mae_results_train))
        print('RSME:', np.mean(rmse_results_train))
        print('\n[TEST]')
    
    print('MAE:', np.mean(mae_results_test))
    print('RSME:', np.mean(rmse_results_test))
    return rmse_results_test

# %% [markdown]
# ### 1. Baseline

# %%
df_baseline = csv_concatenate(os.path.join(data_dir, 'Dataframes','modelling', 'baseline'))
df_baseline['FPTS_pred'] = calculate_FPTS(df_baseline)
# Out:
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=87838), HTML(value='')))

# %%
print('MAE:', calculate_MAE(df_baseline['FPTS_pred'], df_baseline['FPTS']))
print('RMSE:', calculate_RMSE(df_baseline['FPTS_pred'], df_baseline['FPTS']))
# Out:
# MAE: 7.428466892099141
# RMSE: 9.943424501041958

# %% [markdown]
# ### 2. Linear Regression with basic 9 variables

# %%
df_baseline = df_baseline.sort_values(by=['Date','Name']).reset_index(drop=True)

# %%
basic =  ['PTS','3P','AST','TRB','STL','BLK','TOV', 'DD', 'TD']

# %%
X = df_baseline.loc[:, basic]
X = StandardScaler().fit_transform(X)
y = df_baseline['FPTS'].values.reshape(-1,1).flatten()

reg = LinearRegression()
cross_val(reg, X, y)
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# MAE: 7.5196619547369465
# RSME: 9.857817259354775
# [9.82637911562822,
#  9.912110827856841,
#  9.9351595669025,
#  9.758967312942094,
#  9.856469473444218]

# %% [markdown]
# ### 3. Weighted Model

# %% [markdown]
# Choose weighting scheme

# %%
original_stats = ['SG', 'F', 'C', 'PTS', '3P', 'AST', 'TRB', 'STL', 'BLK', 'TOV', 'DD', 'TD', 'MP', 'FT',
                  'FTA', 'FGA', '3PA', 'DRB', 'ORB', 'USG_perc', 'DRtg', 'ORtg', 'AST_perc', 'DRB_perc',
                  'ORB_perc', 'BLK_perc', 'TOV_perc', 'STL_perc', 'eFG_perc', 'FG_perc', '3P_perc', 'FT_perc']
len(original_stats)
# Out:
# 32

# %%
for weighting in ['sqrt', 'linear', 'quad']:
    df_features = csv_concatenate(os.path.join(data_dir, 'Dataframes','modelling', 'features', weighting))  
    
    X = df_features.loc[:, original_stats]
    X = StandardScaler().fit_transform(X)
    y = df_features['FPTS'].values.reshape(-1,1).flatten()

    reg = LinearRegression()
    cross_val(reg, X, y)
# Out:
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# MAE: 7.252586715071312
# RSME: 9.582256361344033
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# MAE: 7.212408190947604
# RSME: 9.543677566513761
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# MAE: 7.196346318159108
# RSME: 9.535559958416505

# %%
pd.DataFrame({'Square Root':[7.252586715071312, 9.582256361344033],
              'Linear':[7.212408190947604, 9.543677566513761],
              'Quadratic':[7.196346318159108, 9.535559958416505]},
             index=['MAE', 'RMSE']).loc[:,['Square Root', 'Linear', 'Quadratic']]
# Out:
#       Square Root    Linear  Quadratic
# MAE      7.252587  7.212408   7.196346
# RMSE     9.582256  9.543678   9.535560

# %%
weighting = 'quad'

df_features = csv_concatenate(os.path.join(data_dir, 'Dataframes','modelling', 'features', weighting))
df_features['FPTS_pred'] = calculate_FPTS(df_features)

print('MAE:', calculate_MAE(df_features['FPTS_pred'], df_features['FPTS']))
print('RMSE:', calculate_RMSE(df_features['FPTS_pred'], df_features['FPTS']))
# Out:
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=75239), HTML(value='')))
# MAE: 7.205878833217748
# RMSE: 9.74749884223535

# %% [markdown]
# Linear Regression with basic 9 variables

# %%
X = df_features.loc[:, basic]
X = StandardScaler().fit_transform(X)
y = df_features['FPTS'].values.reshape(-1,1).flatten()

reg = LinearRegression()
cross_val(reg, X, y, show_train=True)
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# [TRAIN]
# MAE: 7.2865211208929725
# RSME: 9.644153120817592
#
# [TEST]
# MAE: 7.257260826894436
# RSME: 9.590547724625095
# [9.578632095831997,
#  9.633735277617035,
#  9.571478607516134,
#  9.505209719106317,
#  9.66368292305399]

# %%
numerical = ['Salary', 'Starter', 'Rest', 'Rota_All', 'Rota_Pos', 'Home', 'SG', 'F', 'C', 'Value', 'FPTS_std',
             'PTS', '3P', 'AST', 'TRB', 'STL', 'BLK', 'TOV', 'DD', 'TD', 'MP', 'FT', 'FTA', 'FGA', '3PA', 'DRB',
             'ORB', 'USG_perc', 'DRtg', 'ORtg', 'AST_perc', 'DRB_perc', 'ORB_perc', 'BLK_perc', 'TOV_perc', 
             'STL_perc', 'eFG_perc', 'FG_perc', '3P_perc', 'FT_perc']
len(numerical)
# Out:
# 40

# %%
pandas_profiling.ProfileReport(df_features.loc[:, numerical], correlation_threshold=0.9)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>40 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>75239 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>23.0 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>320.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>29 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>5 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_3P"><code>3P</code></a> has 19663 / 26.1% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_3PA"><code>3PA</code></a> is highly correlated with <a href="#pp_var_3P"><code>3P</code></a> (ρ = 0.94413) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_3P_perc"><code>3P_perc</code></a> has 19663 / 26.1% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_AST"><code>AST</code></a> has 4494 / 6.0% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_AST_perc"><code>AST_perc</code></a> has 4246 / 5.6% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_BLK"><code>BLK</code></a> has 15695 / 20.9% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_BLK_perc"><code>BLK_perc</code></a> has 15570 / 20.7% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_DD"><code>DD</code></a> has 54867 / 72.9% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_DRB"><code>DRB</code></a> is highly correlated with <a href="#pp_var_TRB"><code>TRB</code></a> (ρ = 0.97211) <span class="label label-primary">Rejected</span></li><li><a href

# %%
features = ['Salary', 'Starter', 'Rest', 'Rota_All', 'Rota_Pos', 'Home', 'SG', 'F', 'C', 'Value',
            'FPTS_std', 'PTS', '3P', 'AST', 'TRB', 'STL', 'BLK', 'TOV', 'DD', 'TD', 'MP', 'FT', 'ORB',
            'USG_perc', 'DRtg', 'AST_perc', 'DRB_perc', 'ORB_perc', 'BLK_perc', 'TOV_perc', 'STL_perc',
            'eFG_perc', '3P_perc', 'FT_perc']

print(len(features))
X = df_features.loc[:,features]
X = StandardScaler().fit_transform(X)
# Out:
# 34

# %%
model = GradientBoostingRegressor()
model.fit(X, y)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=3, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)

# %%
top_features = pd.Series(model.feature_importances_, index = features).sort_values()
top_features.plot(kind = "barh", figsize=(15,10) ,title='Top Features')
plt.show()

# %%
selected = list(top_features[5:].index)
len(top_features[5:])
# Out:
# 29

# %% [markdown]
# Linear Regression

# %%
X = df_features.loc[:, selected]
X = StandardScaler().fit_transform(X)

reg = LinearRegression()

reg.fit(X, y)
cross_val(reg, X, y)
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# MAE: 7.047783118021587
# RSME: 9.255808363380424
# [9.256338841833921,
#  9.29297446432712,
#  9.265847544370821,
#  9.149737008669288,
#  9.314143957700976]

# %% [markdown]
# ### XGBoost

# %%
from skopt.space import Real, Integer
from skopt.utils import use_named_args
from skopt import gp_minimize
from sklearn.model_selection import cross_val_score
import xgboost as xgb

# %%
reg = xgb.XGBRegressor()
cross_val(reg, X, y, show_train=True)
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# [TRAIN]
# MAE: 6.838196935749404
# RSME: 8.942245507238024
#
# [TEST]
# MAE: 6.905184201750032
# RSME: 9.031552928266342
# [9.013567998451565,
#  9.071195699763058,
#  9.049041061480322,
#  8.933280140479559,
#  9.090679741157205]

# %%
# The list of hyper-parameters we want to optimize. For each one we define the bounds,
# the corresponding scikit-learn parameter name, as well as how to sample values
# from that dimension (`'log-uniform' for the learning rate)

reg = xgb.XGBRegressor()

space  = [Integer(5, 50, name='max_depth'),
          Integer(100, 500, name='n_estimators'),
          Integer(0,5, name='min_child_weight'),
          Real(0.7, 1.0, name='colsample_bytree'), 
          Real(0.7, 1.0, name='colsample_bylevel'),
          Real(0.8, 1.0, name='subsample'),
          Real(0.0, 1.0, name='gamma'),
          Real(0.001, 0.999, "log-uniform", name='learning_rate'),
         ]

# this decorator allows your objective function to receive a the parameters as
# keyword arguments. This is particularly convenient when you want to set scikit-learn
# estimator parameters

@use_named_args(space)
def objective(**params):
    reg.set_params(**params)

    return np.sqrt(-np.mean(cross_val_score(reg, X, y, cv=5, n_jobs=-1, scoring="neg_mean_squared_error")))

# %%
res_gp = gp_minimize(objective, space, n_calls=50, random_state=514, n_random_starts=5, verbose=2)
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 839.7572
# Function value obtained: 13.5489
# Current minimum: 13.5489
# Iteration No: 2 started. Evaluating function at random point.
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 683.0084
# Function value obtained: 9.6967
# Current minimum: 9.6967
# Iteration No: 3 started. Evaluating function at random point.
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 553.4691
# Function value obtained: 9.4723
# Current minimum: 9.4723
# Iteration No: 4 started. Evaluating function at random point.
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 893.0470
# Function value obtained: 14.4509
# Current minimum: 9.4723
# Iteration No: 5 started. Evaluating function at random point.
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 374.4139
# Function value obtained: 9.2518
# Current minimum: 9.2518
# Iteration No: 6 started. Searching for the next optimal point.
# Iteration No: 6 ended. Search finished for the next optimal point.
# Time taken: 78.5787
# Function value obtained: 9.0846
# Current minimum: 9.0846
# Iteration No: 7 started. Searching for the next optimal point.
# Iteration No: 7 ended. Search finished for the next optimal point.
# Time taken: 27.8737
# Function value obtained: 10.4660
# Current minimum: 9.0846
# Iteration No: 8 started. Searching for the next optimal point.
# Iteration No: 8 ended. Search finished for the next optimal point.
# Time taken: 126.1954
# Function value obtained: 9.1340
# Current minimum: 9.0846
# Iteration No: 9 started. Searching for the next optimal point.
# Iteration No: 9 ended. Search finished for the next optimal point.
# Time taken: 193.0704
# Function value obtained: 9.4541
# Current minimum: 9.0846
# Iteration No: 10 started. Searching for the next optimal point.
# Iteration No: 10 ended. Search finished for the next optimal point.
# Time taken: 72.9966
# Function value obtained: 9.0447
# Current minimum: 9.0447
# Iteration No: 11 started. Searching for the next optimal point.
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 79.0657
# Function value obtained: 9.0382
# Current minimum: 9.0382
# Iteration No: 12 started. Searching for the next optimal point.
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 59.3693
# Function value obtained: 9.0240
# Current minimum: 9.0240
# Iteration No: 13 started. Searching for the next optimal point.
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 70.1442
# Function value obtained: 9.0346
# Current minimum: 9.0240
# Iteration No: 14 started. Searching for the next optimal point.
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 54.8497
# Function value obtained: 12.6786
# Current minimum: 9.0240
# Iteration No: 15 started. Searching for the next optimal point.
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 69.5395
# Function value obtained: 9.0252
# Current minimum: 9.0240
# Iteration No: 16 started. Searching for the next optimal point.
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 83.9727
# Function value obtained: 9.0232
# Current minimum: 9.0232
# Iteration No: 17 started. Searching for the next optimal point.
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 40.1782
# Function value obtained: 9.0766
# Current minimum: 9.0232
# Iteration No: 18 started. Searching for the next optimal point.
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 105.9831
# Function value obtained: 9.0193
# Current minimum: 9.0193
# Iteration No: 19 started. Searching for the next optimal point.
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 102.2675
# Function value obtained: 9.0298
# Current minimum: 9.0193
# Iteration No: 20 started. Searching for the next optimal point.
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 22.1577
# Function value obtained: 10.2018
# Current minimum: 9.0193
# Iteration No: 21 started. Searching for the next optimal point.
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 80.4851
# Function value obtained: 9.0237
# Current minimum: 9.0193
# Iteration No: 22 started. Searching for the next optimal point.
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 48.6291
# Function value obtained: 9.0302
# Current minimum: 9.0193
# Iteration No: 23 started. Searching for the next optimal point.
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 94.3301
# Function value obtained: 9.0667
# Current minimum: 9.0193
# Iteration No: 24 started. Searching for the next optimal point.
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 78.0757
# Function value obtained: 9.0300
# Current minimum: 9.0193
# Iteration No: 25 started. Searching for the next optimal point.
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 77.5114
# Function value obtained: 9.0274
# Current minimum: 9.0193
# Iteration No: 26 started. Searching for the next optimal point.
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 60.4925
# Function value obtained: 9.0253
# Current minimum: 9.0193
# Iteration No: 27 started. Searching for the next optimal point.
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 96.0750
# Function value obtained: 9.0215
# Current minimum: 9.0193
# Iteration No: 28 started. Searching for the next optimal point.
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 132.8586
# Function value obtained: 9.0268
# Current minimum: 9.0193
# Iteration No: 29 started. Searching for the next optimal point.
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 22.6590
# Function value obtained: 9.0393
# Current minimum: 9.0193
# Iteration No: 30 started. Searching for the next optimal point.
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 92.6161
# Function value obtained: 9.0224
# Current minimum: 9.0193
# Iteration No: 31 started. Searching for the next optimal point.
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 54.7608
# Function value obtained: 9.0200
# Current minimum: 9.0193
# Iteration No: 32 started. Searching for the next optimal point.
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 73.4031
# Function value obtained: 9.0218
# Current minimum: 9.0193
# Iteration No: 33 started. Searching for the next optimal point.
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 96.4333
# Function value obtained: 9.0257
# Current minimum: 9.0193
# Iteration No: 34 started. Searching for the next optimal point.
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 84.1750
# Function value obtained: 9.0242
# Current minimum: 9.0193
# Iteration No: 35 started. Searching for the next optimal point.
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 38.7574
# Function value obtained: 9.0394
# Current minimum: 9.0193
# Iteration No: 36 started. Searching for the next optimal point.
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 73.7599
# Function value obtained: 9.0308
# Current minimum: 9.0193
# Iteration No: 37 started. Searching for the next optimal point.
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 27.9886
# Function value obtained: 9.0492
# Current minimum: 9.0193
# Iteration No: 38 started. Searching for the next optimal point.
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 102.7344
# Function value obtained: 9.0354
# Current minimum: 9.0193
# Iteration No: 39 started. Searching for the next optimal point.
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 43.9098
# Function value obtained: 9.0236
# Current minimum: 9.0193
# Iteration No: 40 started. Searching for the next optimal point.
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 135.3793
# Function value obtained: 9.0275
# Current minimum: 9.0193
# Iteration No: 41 started. Searching for the next optimal point.
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 86.3960
# Function value obtained: 9.0294
# Current minimum: 9.0193
# Iteration No: 42 started. Searching for the next optimal point.
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 66.4069
# Function value obtained: 9.0292
# Current minimum: 9.0193
# Iteration No: 43 started. Searching for the next optimal point.
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 34.5795
# Function value obtained: 9.0463
# Current minimum: 9.0193
# Iteration No: 44 started. Searching for the next optimal point.
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 65.7521
# Function value obtained: 9.0249
# Current minimum: 9.0193
# Iteration No: 45 started. Searching for the next optimal point.
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 73.4420
# Function value obtained: 9.0227
# Current minimum: 9.0193
# Iteration No: 46 started. Searching for the next optimal point.
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 95.0500
# Function value obtained: 9.0315
# Current minimum: 9.0193
# Iteration No: 47 started. Searching for the next optimal point.
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 59.8251
# Function value obtained: 9.0342
# Current minimum: 9.0193
# Iteration No: 48 started. Searching for the next optimal point.
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 354.2199
# Function value obtained: 9.3790
# Current minimum: 9.0193
# Iteration No: 49 started. Searching for the next optimal point.
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 89.1081
# Function value obtained: 9.0604
# Current minimum: 9.0193
# Iteration No: 50 started. Searching for the next optimal point.
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 22.1651
# Function value obtained: 9.0307
# Current minimum: 9.0193

# %%
print("[Best parameters]")
print(
"""'max_depth':{}, 'n_estimators':{}, 'min_child_weight':{}, 'colsample_bytree':{},
'colsample_bylevel':{}, 'subsample':{}, 'gamma':{}, 'learning_rate':{}""".format(
res_gp.x[0], res_gp.x[1], res_gp.x[2], res_gp.x[3],
res_gp.x[4], res_gp.x[5], res_gp.x[6], res_gp.x[7]))
# Out:
# [Best parameters]
# 'max_depth':5, 'n_estimators':500, 'min_child_weight':5, 'colsample_bytree':0.7,
# 'colsample_bylevel':0.7, 'subsample':0.9397637802105351, 'gamma':0.0, 'learning_rate':0.015427690378899695

# %%
from skopt.plots import plot_convergence

plot_convergence(res_gp);

# %%
best_parameters = {'max_depth':5, 'n_estimators':500, 'min_child_weight':0, 'colsample_bytree':0.7744934433163122,
                   'colsample_bylevel':0.7, 'subsample':0.7, 'gamma':0.8, 'learning_rate':0.010185577044747623}

best_parameters = {'max_depth':5, 'n_estimators':500, 'min_child_weight':0, 'colsample_bytree':0.9087552779394614,
                   'colsample_bylevel':0.7, 'subsample':0.8, 'gamma':0.0, 'learning_rate':0.013402721880461977
                   }
#MAE: 6.852755706901883, RSME: 8.963593652669738

best_parameters = {'max_depth':5, 'n_estimators':500, 'min_child_weight':5, 'colsample_bytree':0.7,
                   'colsample_bylevel':0.7, 'subsample':0.9397637802105351, 'gamma':0.0,
                   'learning_rate':0.015427690378899695}

#MAE: 6.8531269778653465 RSME: 8.964306564892905

best_parameters = {'max_depth':5, 'n_estimators':354, 'min_child_weight':0, 'colsample_bytree':1.0,
                   'colsample_bylevel':0.7, 'subsample':0.7, 'gamma':0.8, 'learning_rate':0.015256854802380305}
#MAE: 6.850690569710392 RSME: 8.966229735232426

best_parameters = {'max_depth':6, 'n_estimators':250, 'min_child_weight':4, 'colsample_bytree':0.6, 
                   'colsample_bylevel':0.7, 'subsample':1.0, 'gamma':0.0, 'learning_rate':0.026944654231987667}

#MAE: 6.848631675865012, RSME: 8.958142274893145
                
reg = xgb.XGBRegressor(**best_parameters)
cross_val(reg, X, y, show_train=True)
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# [TRAIN]
# MAE: 6.551100091016947
# RSME: 8.54150645908519
#
# [TEST]
# MAE: 6.848631675865012
# RSME: 8.958142274893145
# [8.935224253688608,
#  8.995786659437067,
#  8.968571575614034,
#  8.864502552899634,
#  9.026626332826373]

# %% [markdown]
# ###  Neural Network

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import *
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from keras.callbacks import EarlyStopping
# Out:
# /home/kengo/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
es_cb = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto')

# %%
def model_1():
    model = Sequential()
    model.add(Dense(X.shape[1], input_dim=X.shape[1], activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam')
    model.summary()
    return model

# %%
def model_2():
    model = Sequential()
    model.add(Dense(X.shape[1], input_dim=X.shape[1], activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam')
    model.summary()
    return model

# %%
def model_3():
    model = Sequential()
    model.add(Dense(X.shape[1], input_dim=X.shape[1], activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam')
    model.summary()
    return model

# %%
model = KerasRegressor(build_fn=model_1,
                       epochs=30,
                       batch_size=32,
                       validation_split=0.2,
                       shuffle=True,
                       verbose=1)
h1 = model.fit(X, y)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_145 (Dense)            (None, 29)                870
# _________________________________________________________________
# dense_146 (Dense)            (None, 64)                1920
# _________________________________________________________________
# dense_147 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dense_148 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 4,903
# Trainable params: 4,903
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60191 samples, validate on 15048 samples
# Epoch 1/30
# 60191/60191 [==============================] - 6s 106us/step - loss: 100.9857 - val_loss: 86.7216
# Epoch 2/30
# 60191/60191 [==============================] - 5s 78us/step - loss: 86.0878 - val_loss: 83.9704
# Epoch 3/30
# 60191/60191 [==============================] - 5s 82us/step - loss: 84.4102 - val_loss: 82.6419
# Epoch 4/30
# 60191/60191 [==============================] - 5s 78us/step - loss: 83.5502 - val_loss: 82.9844
# Epoch 5/30
# 60191/60191 [==============================] - 5s 86us/step - loss: 82.9174 - val_loss: 81.5879
# Epoch 6/30
# 60191/60191 [==============================] - 4s 70us/step - loss: 81.9892 - val_loss: 81.2879
# Epoch 7/30
# 60191/60191 [==============================] - 4s 67us/step - loss: 81.4855 - val_loss: 80.9979
# Epoch 8/30
# 60191/60191 [==============================] - 5s 78us/step - loss: 81.2637 - val_loss: 81.0155
# Epoch 9/30
# 60191/60191 [==============================] - 5s 80us/step - loss: 81.1101 - val_loss: 83.2094
# Epoch 10/30
# 60191/60191 [==============================] - 5s 91us/step - loss: 80.8750 - val_loss: 80.8213
# Epoch 11/30
# 60191/60191 [==============================] - 5s 83us/step - loss: 80.7726 - val_loss: 80.7427
# Epoch 12/30
#  8352/60191 [===>..........................] - ETA: 4s - loss: 78.7300

# %%
model = KerasRegressor(build_fn=model_2,
                       epochs=30,
                       batch_size=32,
                       validation_split=0.2,
                       shuffle=True,
                       verbose=1)

h2 = model.fit(X, y)

# %%
model = KerasRegressor(build_fn=model_3,
                       epochs=30,
                       batch_size=32,
                       validation_split=0.2,
                       shuffle=True,
                       verbose=1)

h3 = model.fit(X, y)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_141 (Dense)            (None, 29)                870
# _________________________________________________________________
# dense_142 (Dense)            (None, 64)                1920
# _________________________________________________________________
# dense_143 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_144 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 4,903
# Trainable params: 4,903
# Non-trainable params: 0
# _________________________________________________________________
# Train on 
    plt.plot(hist.history['val_loss'])  
    plt.title('Model Loss')  
    plt.ylabel('Loss')  
    plt.xlabel('Epoch')  
    plt.legend(['Train', 'Validation'], loc='upper right')  
    plt.show()

# %%
model = KerasRegressor(build_fn=model_1,
                       epochs=30,
                       batch_size=32,
                       validation_split=0.2,
                       shuffle=True,
                       verbose=1)

kfold = KFold(n_splits=5, shuffle=True)

# %%
results_MAE = cross_val_score(model, X, y, cv=kfold, n_jobs=1, scoring='neg_mean_absolute_error')
results_RMSE = cross_val_score(model, X, y, cv=kfold, n_jobs=1, scoring='neg_mean_squared_error')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_89 (Dense)             (None, 29)                870
# _________________________________________________________________
# dense_90 (Dense)             (None, 64)                1920
# _________________________________________________________________
# dense_91 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_92 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 4,903
# Trainable params: 4,903
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48152 samples, validate on 12039 samples
# Epoch 1/15
# 48152/48152 [==============================] - 5s 94us/step - loss: 124.8280 - val_loss: 86.7580
# Epoch 2/15
# 48152/48152 [==============================] - 4s 75us/step - loss: 106.5999 - val_loss: 84.7563
# Epoch 3/15
# 48152/48152 [==============================] - 4s 77us/step - loss: 103.2503 - val_loss: 83.4305
# Epoch 4/15
# 48152/48152 [==============================] - 4s 77us/step - loss: 101.0866 - val_loss: 81.8036
# Epoch 5/15
# 48152/48152 [==============================] - 4s 77us/step - loss: 98.5975 - val_loss: 83.1958
# Epoch 6/15
# 48152/48152 [==============================] - 4s 81us/step - loss: 96.3806 - val_loss: 80.7360
# Epoch 7/15
# 48152/48152 [==============================] - 4s 85us/step - loss: 96.5383 - val_loss: 81.2409
# Epoch 8/15
# 48152/48152 [==============================] - 4s 89us/step - loss: 95.6541 - val_loss: 80.3745
# Epoch 9/15
# 48152/48152 [==============================] - 4s 91us/step - loss: 94.8187 - val_loss: 80.5472
# Epoch 10/15
# 48152/48152 [==============================] - 4s 75us/step - loss: 93.8816 - val_loss: 80.1734
# Epoch 11/15
# 48152/48152 [==============================] - 4s 81us/step - loss: 93.3151 - val_loss: 83.3161
# Epoch 12/15
# 48152/48152 [==============================] - 4s 87us/step - loss: 93.3084 - val_loss: 80.4791
# Epoch 13/15
# 48152/48152 [==============================] - 4s 77us/step - loss: 92.5721 - val_loss: 80.3341
# Epoch 14/15
# 48152/48152 [==============================] - 4s 81us/step - loss: 92.3557 - val_loss: 80.2809
# Epoch 15/15
# 48152/48152 [==============================] - 4s 74us/step - loss: 91.2894 - val_loss: 80.7272
# 15048/15048 [==============================] - 1s 49us/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_93 (Dense)             (None, 29)                870
# _________________________________________________________________
# dense_94 (Dense)             (None, 64)                1920
# _________________________________________________________________
# dense_95 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_96 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 4,903
# Trainable params: 4,903
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48152 samples, validate on 12039 samples
# Epoch 1/15
# 48152/48152 [==============================] - 5s 114us/step - loss: 119.4189 - val_loss: 87.5742
# Epoch 2/15
# 48152/48152 [==============================] - 4s 88us/step - loss: 101.7355 - val_loss: 83.8893
# Epoch 3/15
# 48152/48152 [==============================] - 4s 86us/step - loss: 99.5391 - val_loss: 81.1952
# Epoch 4/15
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_101 (Dense)            (None, 29)                870
# _________________________________________________________________
# dense_102 (Dense)            (None, 64)                1920
# _________________________________________________________________
# dense_103 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_104 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 4,903
# Trainable params: 4,903
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48152 samples, validate on 12039 samples
# Epoch 1/15
# 48152/48152 [==============================] - 4s 85us/step - loss: 119.3696 - val_loss: 85.6239
# Epoch 2/15
# 48152/48152 [==============================] - 5s 96us/step - loss: 99.5542 - val_loss: 83.9799
# Epoch 3/15
# 48152/48152 [==============================] - 4s 74us/step - loss: 96.6721 - val_loss: 83.4451
# Epoch 4/15
# 48152/48152 [==============================] - 3s 67us/step - loss: 95.8493 - val_loss: 82.8080
# Epoch 5/15
# 48152/48152 [==============================] - 3s 62us/step - loss: 94.1100 - val_loss: 82.1303
# Epoch 6/15
# 48152/48152 [==============================] - 3s 63us/step - loss: 93.5601 - val_loss: 85.0358
# Epoch 7/15
# 48152/48152 [==============================] - 3s 69us/step - loss: 93.3174 - val_loss: 81.2418
# Epoch 8/15
# 48152/48152 [==============================] - 3s 67us/step - loss: 92.7020 - val_loss: 82.0733
# Epoch 9/15
# 48152/48152 [==============================] - 3s 67us/step - loss: 91.2557 - val_loss: 80.7934
# Epoch 10/15
# 48152/48152 [==============================] - 3s 69us/step - loss: 90.8259 - val_loss: 80.3551
# Epoch 11/15
# 48152/48152 [==============================] - 3s 71us/step - loss: 90.6652 - val_loss: 80.4169
# Epoch 12/15
# 48152/48152 [==============================] - 3s 68us/step - loss: 90.4681 - val_loss: 81.9469
# Epoch 13/15
# 48152/48152 [==============================] - 3s 71us/step - loss: 89.7391 - val_loss: 80.6420
# Epoch 14/15
# 48152/48152 [==============================] - 3s 60us/step - loss: 89.7698 - val_loss: 83.4526
# Epoch 15/15
# 48152/48152 [==============================] - 3s 61us/step - loss: 90.0511 - val_loss: 82.0205
# 15048/15048 [==============================] - 1s 51us/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_105 (Dense)            (None, 29)                870
# _________________________________________________________________
# dense_106 (Dense)            (None, 64)                1920
# _________________________________________________________________
# dense_107 (Dense)            (None, 32)                2080
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_108 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 4,903
# Trainable params: 4,903
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48153 samples, validate on 12039 samples
# Epoch 1/15
# 48153/48153 [==============================] - 4s 91us/step - loss: 124.0384 - val_loss: 86.5836
# Epoch 2/15
# 48153/48153 [==============================] - 3s 69us/step - loss: 104.1274 - val_loss: 85.3368
# Epoch 3/15
# 48153/48153 [==============================] - 3s 72us/step - loss: 102.3275 - val_loss: 83.9180
# Epoch 4/15
# 48153/48153 [==============================] - 3s 68us/step - loss: 100.9758 - val_loss: 83.0079
# Epoch 5/15
# 48153/48153 [==============================] - 4s 75us/step - loss: 99.2777 - val_loss: 83.6478
# Epoch 6/15
# 48153/48153 [==============================] - 4s 80us/step - loss: 98.0839 - val_loss: 86.6830
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_128 (Dense)            (None, 1)                 33
# =================================================================
# Total params: 4,903
# Trainable params: 4,903
# Non-trainable params: 0
# _________________________________________________________________
# Train on 48153 samples, validate on 12039 samples
# Epoch 1/15
# 48153/48153 [==============================] - 5s 109us/step - loss: 123.9790 - val_loss: 86.2268
# Epoch 2/15
# 48153/48153 [==============================] - 4s 92us/step - loss: 103.6075 - val_loss: 83.3089
# Epoch 3/15
# 48153/48153 [==============================] - 5s 96us/step - loss: 101.7418 - val_loss: 85.8081
# Epoch 4/15
# 48153/48153 [==============================] - 4s 89us/step - loss: 100.7516 - val_loss: 81.8117
# Epoch 5/15
# 48153/48153 [==============================] - 4s 80us/step - loss: 99.8572 - val_loss: 84.5630
# Epoch 6/15
# 48153/48153 [==============================] - 4s 82us/step - loss: 98.2392 - val_loss: 80.4816
# Epoch 7/15
# 48153/48153 [==============================] - 4s 92us/step - loss: 97.2606 - val_loss: 81.3354
# Epoch 8/15
# 48153/48153 [==============================] - 4s 88us/step - loss: 96.8972 - val_loss: 80.8343
# Epoch 9/15
# 48153/48153 [==============================] - 5s 103us/step - loss: 94.7662 - val_loss: 81.7177
# Epoch 10/15
# 48153/48153 [==============================] - 4s 92us/step - loss: 95.2148 - val_loss: 81.1770
# Epoch 11/15
# 48153/48153 [==============================] - 4s 82us/step - loss: 93.3151 - val_loss: 82.0567
# Epoch 12/15
# 48153/48153 [==============================] - 4s 88us/step - loss: 93.5264 - val_loss: 81.6380
# Epoch 13/15
# 48153/48153 [==============================] - 5s 94us/step - loss: 92.7952 - val_loss: 80.7417
# Epoch 14/15
# 48153/48153 [==============================] - 5s 95us/step - loss: 92.4344 - val_loss: 82.5322
# Epoch 15/15
# 48153/48153 [==============================] - 5s 99us/step - loss: 91.4183 - val_loss: 80.3573
# 15047/15047 [==============================] - 1s 67us/step

# %%
print(np.sqrt(-results_RMSE))
print("Results: %.4f RMSE" % np.sqrt(np.mean(-results_RMSE)))

print(np.sqrt(-results_MAE))
print("Results: %.4f MAE" % np.mean(-results_MAE))
# Out:
# [9.12739247 8.97343087 8.99858694 9.06598791 9.02713493]
# Results: 9.0387 RMSE
# [2.60851797 2.61795802 2.62406186 2.63613281 2.62860647]
# Results: 6.8805 MAE

# %%
results_MAE
# Out:
# array([-6.97001751, -6.99132383, -7.01879362, -6.91880586, -6.82620555])

# %%
results_RMSE.reshape(-1,1)
# Out:
# array([[-80.50648016],
#        [-82.71324899],
#        [-81.89232639],
#        [-84.97260166],
#        [-83.40658684]])

# %%
print(np.sqrt(-results))
print("Results: %.2f RMSE" % np.sqrt(np.mean(-results)))
# Out:
# [9.10785902 9.0541498  9.30030507 9.06696106 8.9603882 ]
# Results: 9.10 RMSE

# %% [markdown]
# ### Prediction

# %%
### Train Test Split
X = df_features.sort_values(by=['Date','Name']).reset_index(drop=True)

target_month = 201803

df_features['Date']

start = 20180301
end = 20180331

test_indices = (df_features['Date'] >= start) & (df_features['Date'] <= end)
train_indices = [not value for value in test_indices]

X_train = df_features.loc[train_indices, selected]
X_test = df_features.loc[test_indices, selected]

y_train = df_features.loc[train_indices, 'FPTS'].values.reshape(-1,1).flatten()
y_test = df_features.loc[test_indices, 'FPTS'].values.reshape(-1,1).flatten()

X_train = StandardScaler().fit_transform(X_train)
X_test = StandardScaler().fit_transform(X_test)

# %%
pred_baseline = df_baseline.loc[(df_baseline['Date'] >= start) & (df_baseline['Date'] <= end), 'FPTS_pred'].reset_index(drop=True)
actual = df_baseline.loc[(df_baseline['Date'] >= start) & (df_baseline['Date'] <= end), 'FPTS'].reset_index(drop=True)
print(calculate_MAE(pred_baseline, actual))
print(calculate_RMSE(pred_baseline, actual))
# Out:
# 7.623819919331103
# 10.061102090024185

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)
pred_lm = reg.predict(X_test)
print(calculate_MAE(pred_lm, y_test))
print(calculate_RMSE(pred_lm, y_test))
# Out:
# 7.116894621253655
# 9.377126363362223

# %%
#best_parameters = {'max_depth':5, 'n_estimators':500, 'min_child_weight':0, 'colsample_bytree':0.7744934433163122,
#                   'colsample_bylevel':0.7, 'subsample':0.7, 'gamma':0.8, 'learning_rate':0.010185577044747623}
#9.358073767342875

best_parameters = {'max_depth':5, 'n_estimators':354, 'min_child_weight':0, 'colsample_bytree':1.0,
                   'colsample_bylevel':0.7, 'subsample':0.7, 'gamma':0.8, 'learning_rate':0.015256854802380305}
#6.993397555914223 9.152592657777618

reg = xgb.XGBRegressor(**best_parameters)
reg.fit(X_train, y_train, verbose=1)
pred_xgb = reg.predict(X_test)
print(calculate_MAE(pred_xgb, y_test))
print(calculate_RMSE(pred_xgb, y_test))
# Out:
# 7.000706675376153
# 9.140396397030514

# %%
def baseline_model():
    model = Sequential()
    model.add(Dense(X_train.shape[1], input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(128, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam')
    model.summary()
    return model

# %%
def advanced_model():
    model = Sequential()
    model.add(Dense(X_train.shape[1], input_dim=X_train.shape[1], activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(64, activation='relu'))
    #model.add(Dropout(0.2))
    model.add(Dense(32, activation='relu'))
    #model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam')
    return model

# %%
model = KerasRegressor(build_fn=baseline_model,
                       epochs=30,
                       batch_size=64,
                       validation_split=0.2,
                       shuffle=True,
                       verbose=1)

h = model.fit(X_train, y_train)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_191 (Dense)            (None, 29)                870
# _________________________________________________________________
# dense_192 (Dense)            (None, 128)               3840
# _________________________________________________________________
# dense_193 (Dense)            (None, 64)                8256
# _________________________________________________________________
# dense_194 (Dense)            (None, 1)                 65
# =================================================================
# Total params: 13,031
# Trainable params: 13,031
# Non-trainable params: 0
# _________________________________________________________________
# Train on 56140 samples, validate on 14036 samples
# Epoch 1/30
# 56140/56140 [==============================] - 7s 124us/step - loss: 107.3528 - val_loss: 86.9025
# Epoch 2/30
# 56140/56140 [==============================] - 5s 82us/step - loss: 85.4848 - val_loss: 83.5527
# Epoch 3/30
# 56140/56140 [==============================] - 5s 89us/step - loss: 83.7691 - val_loss: 82.9099
# Epoch 4/30
# 56140/56140 [==============================] - 5s 93us/step - loss: 82.5673 - val_loss: 82.3614
# Epoch 5/30
# 56140/56140 [==============================] - 6s 99us/step - loss: 81.9585 - val_loss: 84.0049
# Epoch 6/30
# 56140/56140 [==============================] - 5s 93us/step - loss: 81.3169 - val_loss: 81.1206
# Epoch 7/30
# 56140/56140 [==============================] - 6s 99us/step - loss: 81.2096 - val_loss: 81.3716
# Epoch 8/30
# 56140/56140 [==============================] - 5s 98us/step - loss: 80.8035 - val_loss: 81.9920
# Epoch 9/30
# 56140/56140 [==============================] - 6s 99us/step - loss: 80.6363 - val_loss: 80.7754
# Epoch 10/30
# 56140/56140 [==============================] - 6s 100us/step - loss: 80.5449 - val_loss: 81.4247
# Epoch 11/30
# 56140/56140 [==============================] - 6s 101us/step - loss: 80.2284 - val_loss: 81.1155
# Epoch 12/30
# 56140/56140 [==============================] - 5s 97us/step - loss: 79.9389 - val_loss: 81.7475
# Epoch 13/30
# 56140/56140 [==============================] - 5s 94us/step - loss: 79.9246 - val_loss: 81.4713
# Epoch 14/30
# 56140/56140 [==============================] - 6s 99us/step - loss: 79.8737 - val_loss: 82.3734
# Epoch 15/30
# 56140/56140 [==============================] - 6s 104us/step - loss: 79.6746 - val_loss: 81.6686
# Epoch 16/30
# 56140/56140 [==============================] - 6s 99us/step - loss: 79.3652 - val_loss: 81.9140
# Epoch 17/30
# 56140/56140 [==============================] - 5s 95us/step - loss: 79.3962 - val_loss: 81.8464
# Epoch 18/30
# 56140/56140 [==============================] - 6s 99us/step - loss: 79.2614 - val_loss: 80.9881
# Epoch 19/30
# 56140/56140 [==============================] - 6s 99us/step - loss: 79.0536 - val_loss: 81.1435
# Epoch 20/30
# 56140/56140 [==============================] - 6s 101us/step - loss: 78.9053 - val_loss: 81.3939
# Epoch 21/30
# 56140/56140 [==============================] - 6s 100us/step - loss: 78.8747 - val_loss: 82.2077
# Epoch 22/30
# 56140/56140 [==============================] - 5s 97us/step - loss: 78.7931 - val_loss: 81.4493
# Epoch 23/30
# 56140/56140 [==============================] - 6s 99us/step - loss: 78.5028 - val_loss: 81.5501
# Epoch 24/30
# 56140/56140 [==============================] - 6s 105us/step - loss: 78.5116 - val_loss: 81.7388
# Epoch 25/30
# 56140/56140 [==============================] - 5s 87us/step - loss: 78.4741 - val_loss: 81.5916
# Epoch 26/30
# 56140/56140 [==============================] - 4s 78us/step - loss: 78.3436 - val_loss: 82.5608
# Epoch 27/30
# 56140/56140 [==============================] - 5s 85us/step - loss: 78.1550 - val_loss: 82.6537
# Epoch 28/30
# 56140/56140 [==============================] - 5s 83us/step - loss: 77.8556 - val_loss: 82.3351
# Epoch 29/30
# 56140/56140 [==============================] - 5s 97us/step - loss: 77.8582 - val_loss: 82.5096
# Epoch 30/30
# 56140/56140 [==============================] - 4s 79us/step - loss: 77.7385 - val_loss: 84.2035

# %%
pred_nn = model.predict(X_test)
print(calculate_MAE(pred_nn, y_test))
print(calculate_RMSE(pred_nn, y_test))
# Out:
# 5063/5063 [==============================] - 1s 127us/step
# 7.65721060901015
# 10.132008507195883

# %% [markdown]
# ### Write prediction into csv

# %%
df_pred = df_features.loc[test_indices, ['Date', 'Name', 'Team', 'FPTS', 'Pos', 'Salary']]
df_pred['Pred'] = pred_xgb

# %%
df_pred.to_csv(os.path.join(data_dir, 'Prediction/20180514.csv'), index=False)
